# %% [markdown]
# # Andika Rangga Prasetya

# %% [markdown]
# Obj: Mampu memuat data dengan Pandas, Mampu menangani missing values pada dataset, Mampu melakukan manipulasi kolom, Mampu membuat query terhadap dataset, Mampu melakukan grouping terhadap dataset, Mampu melakukan visualisasi sederhana menggunakan Pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import semua library yang diperlukan, disini library yg dibutuhkan adalah lib.pandas dan numpy

# %%
df=pd.read_csv('Pokemon.csv')

# %% [markdown]
# Sintaks diatas yaitu sintaks untuk membaca file yang ingin diproses,dikarenakan file yang ingin diproses adalah csv maka sintaksnya pd(pandas).read_csv(namafile)

# %%
display(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# display(df) yaitu untuk menampilkan dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# df.info() menampilakn informasi type data yang ada pada dalam dataframe dan mencari tahu apakah ada value yang missing

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# menampilkan dataframe dengan 5 baris pertama

# %%
pd.set_option("display.precision", 2)

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# Sama seperti df.head() , jika ditambahkan value dalam kurung maka dataframe akan memuat jumlah baris pada value yang diinput

# %%
df.describe()
# Out:
#             #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# count  800.00  800.00  800.00  800.00   800.00   800.00   800.00  800.00
# mean   362.81  435.10   69.26   79.00    73.84    72.82    71.90   68.28
# std    208.34  119.96   25.53   32.46    31.18    32.72    27.83   29.06
# min      1.00  180.00    1.00    5.00     5.00    10.00    20.00    5.00
# 25%    184.75  330.00   50.00   55.00    50.00    49.75    50.00   45.00
# 50%    364.50  450.00   65.00   75.00    70.00    65.00    70.00   65.00
# 75%    539.25  515.00   80.00  100.00    90.00    95.00    90.00   90.00
# max    721.00  780.00  255.00  190.00   230.00   194.00   230.00  180.00
#
#        Generation
# count      800.00
# mean         3.32
# std          1.66
# min          1.00
# 25%          2.00
# 50%          3.00
# 75%          5.00
# max          6.00

# %% [markdown]
# df.describe()= menunjukkan rangkuman statistik seperti rata-rata, median, dll pada kolom.

# %% [markdown]
# # Menangani value missing

# %%
df.isna().sum()#mengecek data values missing
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# menunjukan apakah dalam suatu dataframe terdapat nilai kosong,
# seperti contoh terdapat nilai kosong sebanyak 386 dalam kolom Type 2

# %%
df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ice         14
# Water       14
# Ghost       14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# Mencari tahu nilai dengan jumlah nilai pada suatu kolom

# %%
mode=df['Type 2'].mode()[0]

# %% [markdown]
# Sintaks diatas adalah salah satu cara dalam menangani value missing pada kolom yang nilai valuenya bukan Integer melainkan Object/String,"Mode" adalah nilai modus yang akan digunakan untuk mengisi nilai kosong/NaN/null, akan tetapi ini masih diproses dalam proses program dibelakang, apabila kita run dan kita tampilkan maka nilai Nan/kosong masih exist

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# karena sudah mendeklarasikan rumus mode untuk menangani missing value makas hasil proses tadi tersimpan dalam mode belum dilakukan inplace

# %%
print(mode)
# Out:
# Flying

# %% [markdown]
# mencari tahu nilai modus dalam mode yg sudah dideklarasikan

# %%
df['Type 2'].fillna(mode,inplace=True)

# %% [markdown]
# berikut ini memasukan mode yang tadi sudah diproses kedalam dataframe dengan nilai True

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire  Flying    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Manipulasi

# %%
Pokemon=df.copy()#bagian manipulasi

# %% [markdown]
# di bagian ini membuat copy atau backup dataframe sebelumnya untuk dilakukan manipulasi dataframe

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# mencari tahu jumalh baris dan kolom

# %%
Pokemon['Fatality']= df.Attack + df.Speed`

# %% [markdown]
# Disini membuat kolom baru dengan nama Fatality yang didalamnya terdapat nilai dari masing-masing Pokemon dengan cara menambahkan setiap value Attack dengan Speed

# %%
Pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire  Flying    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
Pokemon.shape
# Out:
# (800, 14)

# %%
Pokemon['Fatality'].value_counts()
# Out:
# 115    29
# 130    28
# 145    24
# 140    23
# 100    21
#        ..
# 153     1
# 142     1
# 131     1
# 123     1
# 330     1
# Name: Fatality, Length: 169, dtype: int64

# %%
pemukul=df[df['Attack']>=100] #query data dengan nilai attack lebih dari 100

# %% [markdown]
# Menegolompokan data yang dimana nilai attack lebih nari 100 dengan membuat variabel pemukul terlebih dahulu

# %%
pemukul
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# 12     9    BlastoiseMega Blastoise    Water  Flying    630  79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495  65     150
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[
    (df['Type 1']=='Water')&
    (df['Attack']>=95)
].groupby(['Name','Speed'])['Defense'].count()
# Out:
# Name                     Speed
# BlastoiseMega Blastoise  78       1
# Carracosta               32       1
# Cloyster                 70       1
# Crawdaunt                55       1
# Feraligatr               78       1
# Floatzel                 115      1
# Greninja                 122      1
# Gyarados                 81       1
# GyaradosMega Gyarados    81       1
# Huntail                  52       1
# Kingdra                  85       1
# Kingler                  75       1
# Krabby                   50       1
# Kyogre                   90       1
# KyogrePrimal Kyogre      90       1
# Manaphy                  100      1
# Octillery                45       1
# Palkia                   100      1
# Poliwrath                70       1
# Qwilfish                 85       1
# Samurott                 70       1
# Seismitoad               74       1
# Sharpedo                 95       1
# SharpedoMega Sharpedo    105      1
# Simipour                 101      1
# ...

# %% [markdown]
# Sitaks diatas mealkukan groupby yang artinya menampilkan data dengan cara dibentuk dengan list. data diatas adalah dimana ingin menampilkan pokemon jenis air yang nilai attacknya lebih dari 95, dan ditampilkan dalam nama pokemon dan nilai speednya

# %% [markdown]
# # Visualisasi

# %%
# %matplotlib inline

# %% [markdown]
# Matplotlib digunakan untuk membuat plot sebagai visualisasi sederhana. Matplobini adalah sebuah library

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire  Flying    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df['Name'].value_counts()
# Out:
# Unown                    1
# Boldore                  1
# Audino                   1
# AlakazamMega Alakazam    1
# Honedge                  1
#                         ..
# AegislashBlade Forme     1
# Quagsire                 1
# Dragonite                1
# Volcanion                1
# Starly                   1
# Name: Name, Length: 800, dtype: int64

# %%
df[df["Type 1"] == "Fire"].groupby("Attack")["Speed"].sum().plot()
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
Pokemon[Pokemon["Type 1"] == "Water"].groupby("Attack")["Fatality"].sum().plot()
# Out:
# <AxesSubplot:xlabel='Attack'>

# %% [markdown]
# Kesimpulan: Untuk jenis pokemon yang banyak type adalah jenis pokemon tipe Air/water
